# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key
temp_units = "imperial"

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "Output/weather_df.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# define url
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={api_key}&units={temp_units}&q="

# define count of pass throughs
count_one = 0

# %%
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
# If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 582

# %%
# set lists for the dataframe
city_two = []
cloudinesses = []
dates = []
humidities = []
lats = []
lngs = []
max_temps = []
wind_speeds = []
countries = []

# set initial count quantities for organization
count_one = 0
set_one = 1

# loops for creating dataframe columns
for city in cities:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudinesses.append(response['clouds']['all'])
        countries.append(response['sys']['country'])
        dates.append(response['dt'])
        humidities.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        wind_speeds.append(response['wind']['speed'])
        if count_one > 48:
            count_one = 1
            set_one += 1
            city_two.append(city)
        else:
            count_one += 1
            city_two.append(city)
        print(f"Processing Record {count_one} of Set {set_one} | {city}")
    except Exception:
        print("City not found. Skipping...")
print("------------------------------\nData Retrieval Complete\n------------------------------")
# Out:
# Processing Record 1 of Set 1 | shache
# Processing Record 2 of Set 1 | yorosso
# City not found. Skipping...
# Processing Record 3 of Set 1 | hobart
# Processing Record 4 of Set 1 | adrar
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | kaitangata
# Processing Record 7 of Set 1 | cabra
# Processing Record 8 of Set 1 | lorengau
# Processing Record 9 of Set 1 | yaring
# Processing Record 10 of Set 1 | bredasdorp
# Processing Record 11 of Set 1 | zhangjiakou
# Processing Record 12 of Set 1 | butaritari
# Processing Record 13 of Set 1 | srirampur
# Processing Record 14 of Set 1 | pisco
# Processing Record 15 of Set 1 | labuhan
# Processing Record 16 of Set 1 | new norfolk
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | norman wells
# Processing Record 19 of Set 1 | cape town
# Processing Record 20 of Set 1 | yellowknife
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | chuy
# Processing Record 23 of Set 1 | port alfred
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | luderitz
# City not found. Skipping...
# Processing Record 26 of Set 1 | oschersleben
# Processing Record 27 of Set 1 | keflavik
# Processing Record 28 of Set 1 | janakkala
# Processing Record 29 of Set 1 | pimenta bueno
# Processing Record 30 of Set 1 | aswan
# Processing Record 31 of Set 1 | flinders
# City not found. Skipping...
# Processing Record 32 of Set 1 | takanabe
# Processing Record 33 of Set 1 | ushuaia
# City not found. Skipping...
# Processing Record 34 of Set 1 | nanortalik
# City not found. Skipping...
# Processing Record 35 of Set 1 | san quintin
# Processing Record 36 of Set 1 | deputatskiy
# Processing Record 37 of Set 1 | xinan
# Processing Record 38 of Set 1 | briancon
# City not found. Skipping...
# Processing Record 39 of Set 1 | constitucion
# Processing Record 40 of Set 1 | bethel
# Processing Record 41 of Set 1 | puerto escondido
# Processing Record 42 of Set 1 | talnakh
# Processing Record 43 of Set 1 | vao
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 44 of Set 1 | yarmouth
# Processing Record 45 of Set 1 | puerto madryn
# Processing Record 46 of Set 1 | langxiang
# Processing Record 47 of Set 1 | imbituba
# Processing Record 48 of Set 1 | backa palanka
# Processing Record 49 of Set 1 | arraial do cabo
# City not found. Skipping...
# Processing Record 1 of Set 2 | santa maria
# Processing Record 2 of Set 2 | lompoc
# Processing Record 3 of Set 2 | albany
# Processing Record 4 of Set 2 | torbay
# Processing Record 5 of Set 2 | bowen
# Processing Record 6 of Set 2 | avarua
# City not found. Skipping...
# Processing Record 7 of Set 2 | dongkan
# Processing Record 8 of Set 2 | kuching
# Processing Record 9 of Set 2 | tura
# Processing Record 10 of Set 2 | mahebourg
# Processing Record 11 of Set 2 | kapaa
# Processing Record 12 of Set 2 | puro
# Processing Record 13 of Set 2 | hasaki
# Processing Record 14 of Set 2 | nieves
# City not found. Skipping...
# Processing Record 15 of Set 2 | namibe
# Processing Record 16 of Set 2 | harrisburg
# Processing Record 17 of Set 2 | hermanus
# Processing Record 18 of Set 2 | sirvintos
# Processing Record 19 of Set 2 | barrow
# Processing Record 20 of Set 2 | kodiak
# Processing Record 21 of Set 2 | altay
# Processing Record 22 of Set 2 | ponta do sol
# Processing Record 23 of Set 2 | port-cartier
# Processing Record 24 of Set 2 | viedma
# Processing Record 25 of Set 2 | banda aceh
# Processing Record 26 of Set 2 | clyde river
# City not found. Skipping...
# Processing Record 27 of Set 2 | khatanga
# City not found. Skipping...
# Processing Record 28 of Set 2 | acajutla
# Processing Record 29 of Set 2 | sioux lookout
# Processing Record 30 of Set 2 | thompson
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 31 of Set 2 | ayan
# City not found. Skipping...
# Processing Record 32 of Set 2 | tirumullaivasal
# Processing Record 33 of Set 2 | dukat
# Processing Record 34 of Set 2 | birobidzhan
# Processing Record 35 of Set 2 | matamoros
# Processing Record 36 of Set 2 | anadyr
# Processing Record 37 of Set 2 | hami
# Processing Record 38 of Set 2 | aranos
# Processing Record 39 of Set 2 | mys shmidta
# Processing Record 40 of Set 2 | bluff
# Processing Record 41 of Set 2 | cabo san lucas
# Processing Record 42 of Set 2 | yulara
# Processing Record 43 of Set 2 | visnes
# Processing Record 44 of Set 2 | port blair
# Processing Record 45 of Set 2 | ulladulla
# City not found. Skipping...
# Processing Record 46 of Set 2 | mataura
# Processing Record 47 of Set 2 | egvekinot
# Processing Record 48 of Set 2 | ibra
# Processing Record 49 of Set 2 | hithadhoo
# City not found. Skipping...
# Processing Record 1 of Set 3 | longyearbyen
# Processing Record 2 of Set 3 | port hardy
# City not found. Skipping...
# Processing Record 3 of Set 3 | lagoa
# Processing Record 4 of Set 3 | nipawin
# Processing Record 5 of Set 3 | puerto ayora
# Processing Record 6 of Set 3 | sangar
# Processing Record 7 of Set 3 | sao joao da barra
# Processing Record 8 of Set 3 | riyadh
# Processing Record 9 of Set 3 | nemuro
# Processing Record 10 of Set 3 | vestmannaeyjar
# Processing Record 11 of Set 3 | homer
# City not found. Skipping...
# Processing Record 12 of Set 3 | vaini
# Processing Record 13 of Set 3 | castro
# Processing Record 14 of Set 3 | dikson
# Processing Record 15 of Set 3 | kiunga
# Processing Record 16 of Set 3 | mount isa
# City not found. Skipping...
# Processing Record 17 of Set 3 | yenagoa
# Processing Record 18 of Set 3 | guabito
# Processing Record 19 of Set 3 | fortuna
# Processing Record 20 of Set 3 | carnarvon
# Processing Record 21 of Set 3 | kalanchak
# Processing Record 22 of Set 3 | airai
# Processing Record 23 of Set 3 | dingle
# Processing Record 24 of Set 3 | lucea
# Processing Record 25 of Set 3 | ponta delgada
# Processing Record 26 of Set 3 | antofagasta
# City not found. Skipping...
# Processing Record 27 of Set 3 | qaanaaq
# Processing Record 28 of Set 3 | wairoa
# Processing Record 29 of Set 3 | tuatapere
# Processing Record 30 of Set 3 | ilulissat
# Processing Record 31 of Set 3 | cherskiy
# Processing Record 32 of Set 3 | husavik
# Processing Record 33 of Set 3 | terney
# Processing Record 34 of Set 3 | saskylakh
# Processing Record 35 of Set 3 | provideniya
# Processing Record 36 of Set 3 | victoria
# Processing Record 37 of Set 3 | san cristobal
# Processing Record 38 of Set 3 | thinadhoo
# Processing Record 39 of Set 3 | hobyo
# Processing Record 40 of Set 3 | richards bay
# Processing Record 41 of Set 3 | san carlos de bariloche
# Processing Record 42 of Set 3 | hit
# Processing Record 43 of Set 3 | east london
# Processing Record 44 of Set 3 | tasiilaq
# Processing Record 45 of Set 3 | ondjiva
# Processing Record 46 of Set 3 | ballina
# Processing Record 47 of Set 3 | pedernales
# Processing Record 48 of Set 3 | katsuura
# Processing Record 49 of Set 3 | ternate
# Processing Record 1 of Set 4 | salalah
# Processing Record 2 of Set 4 | chapais
# Processing Record 3 of Set 4 | ostrovnoy
# Processing Record 4 of Set 4 | atuona
# Processing Record 5 of Set 4 | palmer
# Processing Record 6 of Set 4 | grindavik
# Processing Record 7 of Set 4 | hualmay
# Processing Record 8 of Set 4 | cidreira
# Processing Record 9 of Set 4 | kingman
# Processing Record 10 of Set 4 | chaumont
# Processing Record 11 of Set 4 | jiuquan
# Processing Record 12 of Set 4 | merritt
# Processing Record 13 of Set 4 | nata
# Processing Record 14 of Set 4 | arauco
# Processing Record 15 of Set 4 | bonavista
# Processing Record 16 of Set 4 | jambi
# Processing Record 17 of Set 4 | wilmington
# City not found. Skipping...
# Processing Record 18 of Set 4 | severo-kurilsk
# Processing Record 19 of Set 4 | san patricio
# Processing Record 20 of Set 4 | tautira
# Processing Record 21 of Set 4 | faanui
# City not found. Skipping...
# Processing Record 22 of Set 4 | saint-paul
# Processing Record 23 of Set 4 | shingu
# Processing Record 24 of Set 4 | carballo
# Processing Record 25 of Set 4 | sunam
# Processing Record 26 of Set 4 | katobu
# Processing Record 27 of Set 4 | alberdi
# Processing Record 28 of Set 4 | shenzhen
# Processing Record 29 of Set 4 | saint-philippe
# Processing Record 30 of Set 4 | chama
# City not found. Skipping...
# Processing Record 31 of Set 4 | lagos
# Processing Record 32 of Set 4 | muli
# Processing Record 33 of Set 4 | narsaq
# Processing Record 34 of Set 4 | bedele
# Processing Record 35 of Set 4 | aleksandrov gay
# Processing Record 36 of Set 4 | caravelas
# Processing Record 37 of Set 4 | lebu
# Processing Record 38 of Set 4 | nikolskoye
# Processing Record 39 of Set 4 | neiafu
# Processing Record 40 of Set 4 | krasnystaw
# Processing Record 41 of Set 4 | nyurba
# Processing Record 42 of Set 4 | coquimbo
# Processing Record 43 of Set 4 | ahuimanu
# Processing Record 44 of Set 4 | ambilobe
# Processing Record 45 of Set 4 | kanye
# Processing Record 46 of Set 4 | buala
# Processing Record 47 of Set 4 | atar
# Processing Record 48 of Set 4 | gbadolite
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 49 of Set 4 | sola
# Processing Record 1 of Set 5 | saryagash
# Processing Record 2 of Set 5 | praya
# Processing Record 3 of Set 5 | ribeira grande
# Processing Record 4 of Set 5 | hilo
# Processing Record 5 of Set 5 | minyar
# Processing Record 6 of Set 5 | turayf
# Processing Record 7 of Set 5 | mangan
# Processing Record 8 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 9 of Set 5 | sistranda
# City not found. Skipping...
# Processing Record 10 of Set 5 | berlevag
# Processing Record 11 of Set 5 | coihaique
# City not found. Skipping...
# Processing Record 12 of Set 5 | pevek
# Processing Record 13 of Set 5 | hay river
# Processing Record 14 of Set 5 | chicama
# Processing Record 15 of Set 5 | canete
# Processing Record 16 of Set 5 | iqaluit
# Processing Record 17 of Set 5 | bilma
# Processing Record 18 of Set 5 | cayenne
# Processing Record 19 of Set 5 | baykit
# Processing Record 20 of Set 5 | nguru
# Processing Record 21 of Set 5 | ikungi
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 22 of Set 5 | saint-leu
# Processing Record 23 of Set 5 | wanning
# Processing Record 24 of Set 5 | lavrentiya
# Processing Record 25 of Set 5 | upernavik
# Processing Record 26 of Set 5 | menongue
# Processing Record 27 of Set 5 | codrington
# Processing Record 28 of Set 5 | morros
# Processing Record 29 of Set 5 | bafoulabe
# Processing Record 30 of Set 5 | san pedro
# Processing Record 31 of Set 5 | hamilton
# Processing Record 32 of Set 5 | itoman
# Processing Record 33 of Set 5 | eydhafushi
# Processing Record 34 of Set 5 | touros
# Processing Record 35 of Set 5 | rivadavia
# Processing Record 36 of Set 5 | asyut
# Processing Record 37 of Set 5 | caxias
# Processing Record 38 of Set 5 | andira
# Processing Record 39 of Set 5 | mar del plata
# Processing Record 40 of Set 5 | college
# City not found. Skipping...
# Processing Record 41 of Set 5 | reinach
# Processing Record 42 of Set 5 | araguaina
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 43 of Set 5 | haimen
# Processing Record 44 of Set 5 | alvand
# Processing Record 45 of Set 5 | grafton
# Processing Record 46 of Set 5 | batticaloa
# Processing Record 47 of Set 5 | rio gallegos
# Processing Record 48 of Set 5 | vardo
# Processing Record 49 of Set 5 | nicolas bravo
# Processing Record 1 of Set 6 | chokurdakh
# Processing Record 2 of Set 6 | leningradskiy
# Processing Record 3 of Set 6 | geraldton
# Processing Record 4 of Set 6 | buchanan
# Processing Record 5 of Set 6 | port elizabeth
# Processing Record 6 of Set 6 | boddam
# Processing Record 7 of Set 6 | kirkenaer
# Processing Record 8 of Set 6 | leh
# Processing Record 9 of Set 6 | komyshuvakha
# Processing Record 10 of Set 6 | qaqortoq
# Processing Record 11 of Set 6 | erdenet
# Processing Record 12 of Set 6 | ketchikan
# Processing Record 13 of Set 6 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 14 of Set 6 | tiksi
# Processing Record 15 of Set 6 | itinga
# Processing Record 16 of Set 6 | shirokiy
# Processing Record 17 of Set 6 | jacareacanga
# Processing Record 18 of Set 6 | abalak
# Processing Record 19 of Set 6 | zhengjiatun
# Processing Record 20 of Set 6 | mirabad
# Processing Record 21 of Set 6 | sitka
# Processing Record 22 of Set 6 | miri
# Processing Record 23 of Set 6 | atherton
# Processing Record 24 of Set 6 | lasa
# Processing Record 25 of Set 6 | georgetown
# Processing Record 26 of Set 6 | kem
# Processing Record 27 of Set 6 | vila
# City not found. Skipping...
# Processing Record 28 of Set 6 | alofi
# Processing Record 29 of Set 6 | qeshm
# Processing Record 30 of Set 6 | paamiut
# Processing Record 31 of Set 6 | puri
# Processing Record 32 of Set 6 | ust-nera
# Processing Record 33 of Set 6 | basco
# City not found. Skipping...
# Processing Record 34 of Set 6 | kruisfontein
# Processing Record 35 of Set 6 | aykhal
# Processing Record 36 of Set 6 | saldanha
# Processing Record 37 of Set 6 | englewood
# Processing Record 38 of Set 6 | butembo
# Processing Record 39 of Set 6 | vanimo
# Processing Record 40 of Set 6 | ridgecrest
# Processing Record 41 of Set 6 | bathsheba
# Processing Record 42 of Set 6 | port keats
# City not found. Skipping...
# Processing Record 43 of Set 6 | celestun
# Processing Record 44 of Set 6 | esso
# Processing Record 45 of Set 6 | port lincoln
# Processing Record 46 of Set 6 | fortuna foothills
# Processing Record 47 of Set 6 | lumatil
# Processing Record 48 of Set 6 | tabou
# Processing Record 49 of Set 6 | pierre
# Processing Record 1 of Set 7 | pathein
# Processing Record 2 of Set 7 | baruun-urt
# Processing Record 3 of Set 7 | hailey
# Processing Record 4 of Set 7 | sami
# Processing Record 5 of Set 7 | chara
# Processing Record 6 of Set 7 | dunedin
# Processing Record 7 of Set 7 | benguela
# City not found. Skipping...
# Processing Record 8 of Set 7 | aklavik
# Processing Record 9 of Set 7 | privas
# Processing Record 10 of Set 7 | huntsville
# Processing Record 11 of Set 7 | brae
# Processing Record 12 of Set 7 | antalaha
# Processing Record 13 of Set 7 | petauke
# Processing Record 14 of Set 7 | komsomolskiy
# City not found. Skipping...
# Processing Record 15 of Set 7 | mount gambier
# Processing Record 16 of Set 7 | necochea
# Processing Record 17 of Set 7 | emba
# Processing Record 18 of Set 7 | tuktoyaktuk
# Processing Record 19 of Set 7 | kaeo
# Processing Record 20 of Set 7 | fort nelson
# Processing Record 21 of Set 7 | katangli
# Processing Record 22 of Set 7 | robertsport
# Processing Record 23 of Set 7 | lakselv
# Processing Record 24 of Set 7 | nadym
# Processing Record 25 of Set 7 | yadgir
# Processing Record 26 of Set 7 | jasper
# City not found. Skipping...
# Processing Record 27 of Set 7 | puerto baquerizo moreno
# Processing Record 28 of Set 7 | bristol
# Processing Record 29 of Set 7 | tecoanapa
# Processing Record 30 of Set 7 | bara
# Processing Record 31 of Set 7 | vila franca do campo
# Processing Record 32 of Set 7 | gushikawa
# Processing Record 33 of Set 7 | kenai
# Processing Record 34 of Set 7 | bireun
# City not found. Skipping...
# Processing Record 35 of Set 7 | ushtobe
# Processing Record 36 of Set 7 | esperance
# Processing Record 37 of Set 7 | ozernovskiy
# Processing Record 38 of Set 7 | rodeo
# Processing Record 39 of Set 7 | nacala
# Processing Record 40 of Set 7 | mareeba
# Processing Record 41 of Set 7 | camargo
# Processing Record 42 of Set 7 | bilibino
# Processing Record 43 of Set 7 | kargasok
# Processing Record 44 of Set 7 | aksarka
# City not found. Skipping...
# Processing Record 45 of Set 7 | tamasane
# Processing Record 46 of Set 7 | dire
# Processing Record 47 of Set 7 | ewo
# Processing Record 48 of Set 7 | oksbol
# Processing Record 49 of Set 7 | vila velha
# City not found. Skipping...
# Processing Record 1 of Set 8 | wanaka
# Processing Record 2 of Set 8 | hofn
# Processing Record 3 of Set 8 | rio grande
# Processing Record 4 of Set 8 | goure
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 5 of Set 8 | padang
# Processing Record 6 of Set 8 | carbonia
# Processing Record 7 of Set 8 | altar
# Processing Record 8 of Set 8 | yar-sale
# Processing Record 9 of Set 8 | tevriz
# Processing Record 10 of Set 8 | davila
# City not found. Skipping...
# Processing Record 11 of Set 8 | lata
# Processing Record 12 of Set 8 | grand centre
# Processing Record 13 of Set 8 | nguruka
# Processing Record 14 of Set 8 | alikalia
# Processing Record 15 of Set 8 | souillac
# Processing Record 16 of Set 8 | ahipara
# Processing Record 17 of Set 8 | millington
# Processing Record 18 of Set 8 | springbok
# Processing Record 19 of Set 8 | anapolis
# Processing Record 20 of Set 8 | sao gabriel da cachoeira
# Processing Record 21 of Set 8 | radom
# Processing Record 22 of Set 8 | vestmanna
# Processing Record 23 of Set 8 | mlimba
# Processing Record 24 of Set 8 | rio cuarto
# City not found. Skipping...
# Processing Record 25 of Set 8 | raudeberg
# Processing Record 26 of Set 8 | grand river south east
# Processing Record 27 of Set 8 | clinton
# Processing Record 28 of Set 8 | cap malheureux
# Processing Record 29 of Set 8 | kavaratti
# Processing Record 30 of Set 8 | sindi
# Processing Record 31 of Set 8 | guerrero negro
# Processing Record 32 of Set 8 | alenquer
# Processing Record 33 of Set 8 | balkhash
# Processing Record 34 of Set 8 | auki
# Processing Record 35 of Set 8 | ariquemes
# Processing Record 36 of Set 8 | sladkovo
# Processing Record 37 of Set 8 | fort dodge
# Processing Record 38 of Set 8 | guarapari
# Processing Record 39 of Set 8 | bakchar
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 40 of Set 8 | pichayevo
# Processing Record 41 of Set 8 | coahuayana
# Processing Record 42 of Set 8 | yeniseysk
# Processing Record 43 of Set 8 | formosa
# Processing Record 44 of Set 8 | muriwai beach
# Processing Record 45 of Set 8 | nome
# Processing Record 46 of Set 8 | ayagoz
# Processing Record 47 of Set 8 | srednekolymsk
# Processing Record 48 of Set 8 | buraydah
# Processing Record 49 of Set 8 | salinopolis
# City not found. Skipping...
# Processing Record 1 of Set 9 | hovd
# Processing Record 2 of Set 9 | beyneu
# Processing Record 3 of Set 9 | shimoda
# Processing Record 4 of Set 9 | nivala
# Processing Record 5 of Set 9 | pleasant point
# Processing Record 6 of Set 9 | sayyan
# Processing Record 7 of Set 9 | osakarovka
# Processing Record 8 of Set 9 | pochutla
# Processing Record 9 of Set 9 | bubaque
# Processing Record 10 of Set 9 | manakara
# Processing Record 11 of Set 9 | harihar
# Processing Record 12 of Set 9 | bismarck
# Processing Record 13 of Set 9 | leavenworth
# Processing Record 14 of Set 9 | amuntai
# Processing Record 15 of Set 9 | sinnamary
# Processing Record 16 of Set 9 | half moon bay
# Processing Record 17 of Set 9 | teahupoo
# City not found. Skipping...
# City not found. Skipping...
